# %%
# %load_ext autoreload
# %autoreload 2
from kmeans import Kmeans
from gmm import GaussianMixturesEM
from utils import load_data

# %%
data = load_data()
# Out:
# data (500, 2) loaded

# %% [markdown]
# # Kmeans

# %%
km = Kmeans(data, K=4, tol=0.01)
_ = km.train(notebook_viz=True)
# Out:
# Algorithm has converged after 8 iterations.

# %% [markdown]
# # Gaussian Mixtures

# %% [markdown]
# with or without kmeans initialisation

# %%
gm = GaussianMixturesEM(data=data, K=4, tol=0.1)
_ = gm.train(kmeans_init=False, notebook_viz=True)
# Out:
# Algorithm has converged after 27 iterations
